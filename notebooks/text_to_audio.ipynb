# %% [markdown]
# # Text to Audio

# %% [markdown]
# Libraries

# %%
import pyttsx3

# %% [markdown]
# <b>pyttsx3</b><br>
# Free But very generic

# %%
engine = pyttsx3.init()
engine.say("Hello World")
engine.runAndWait()
