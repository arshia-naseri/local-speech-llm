# %% [markdown]
# # Text to Audio

# %% [markdown]
# <b>pyttsx3</b><br>
# Free But very generic

# %%
import pyttsx3
engine = pyttsx3.init()
# Get voices
voices = engine.getProperty("voices")
print(voices[0].languages)
for v in voices:
    if "en_US" in v.languages:
        print(f"{v.languages} id: {v.id}, name: {v.name}")
# Out:
# ['en_US']
# ['en_US'] id: com.apple.speech.synthesis.voice.Albert, name: Albert
# ['en_US'] id: com.apple.speech.synthesis.voice.BadNews, name: Bad News
# ['en_US'] id: com.apple.speech.synthesis.voice.Bahh, name: Bahh
# ['en_US'] id: com.apple.speech.synthesis.voice.Bells, name: Bells
# ['en_US'] id: com.apple.speech.synthesis.voice.Boing, name: Boing
# ['en_US'] id: com.apple.speech.synthesis.voice.Bubbles, name: Bubbles
# ['en_US'] id: com.apple.speech.synthesis.voice.Cellos, name: Cellos
# ['en_US'] id: com.apple.speech.synthesis.voice.Deranged, name: Wobble
# ['en_US'] id: com.apple.eloquence.en-US.Eddy, name: Eddy (English (US))
# ['en_US'] id: com.apple.eloquence.en-US.Flo, name: Flo (English (US))
# ['en_US'] id: com.apple.speech.synthesis.voice.Fred, name: Fred
# ['en_US'] id: com.apple.speech.synthesis.voice.GoodNews, name: Good News
# ['en_US'] id: com.apple.eloquence.en-US.Grandma, name: Grandma (English (US))
# ['en_US'] id: com.apple.eloquence.en-US.Grandpa, name: Grandpa (English (US))
# ['en_US'] id: com.apple.speech.synthesis.voice.Hysterical, name: Jester
# ['en_US'] id: com.apple.speech.synthesis.voice.Junior, name: Junior
# ['en_US'] id: com.apple.speech.synthesis.voice.Kathy, name: Kathy
# ['en_US'] id: com.apple.speech.synthesis.voice.Organ, name: Organ
# ['en_US'] id: com.apple.speech.synthesis.voice.Princess, name: Superstar
# ['en_US'] id: com.apple.speech.synthesis.voice.Ralph, name: Ralph
# ['en_US'] id: com.apple.eloquence.en-US.Reed, name: Reed (English (US))
# ['en_US'] id: com.apple.eloquence.en-US.Rocko, name: Rocko (English (US))
# ['en_US'] id: com.apple.voice.compact.en-US.Samantha, name: Samantha
# ['en_US'] id: com.apple.eloquence.en-US.Sandy, name: Sandy (English (US))
# ['en_US'] id: com.apple.eloquence.en-US.Shelley, name: Shelley (English (US))
# ['en_US'] id: com.apple.speech.synthesis.voice.Trinoids, name: Trinoids
# ['en_US'] id: com.apple.speech.synthesis.voice.Whisper, name: Whisper
# ['en_US'] id: com.apple.speech.synthesis.voice.Zarvox, name: Zarvox

# %%
# engine.setProperty("voice","com.apple.speech.synthesis.voice.Princess")
engine.say("Hello World")
engine.runAndWait()

# %% [markdown]
# # Google Text-to-Speech

# %%
from gtts import gTTS
from playsound3 import playsound

tts = gTTS("Hello World", lang="en")
tts.save("hello.mp3")         # save audio file

playsound("hello.mp3")        # play it

# %% [markdown]
# <b>Piper</b><br>
# Much faster and can download voices from https://huggingface.co/rhasspy/piper-voices/tree/main

# %%
import piper
import subprocess
import tempfile, os 

text = "Hello world. Where is Canada?"
voicePath = "../voices/en_US-joe-medium.onnx"
process = subprocess.Popen(
    [
        "piper",
        "--model", voicePath,
        "--output_file", "output.wav",
        "--length-scale", "1.1",
        "--sentence-silence", "0.3",
    ],
    stdin=subprocess.PIPE,
    stdout=subprocess.PIPE,
)

audio, _ = process.communicate(text.encode("utf-8"))

subprocess.run(["afplay", "output.wav"])
# Out:
# CompletedProcess(args=['afplay', 'output.wav'], returncode=0)
